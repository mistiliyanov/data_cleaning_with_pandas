# %% [markdown]
# # Cleanining Project "Billboard"

# %%
# my imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Date cleaning and Tidying

# %%
bilboard = pd.read_csv('data/billboard.csv')

# %%
bilboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  92.0   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  68.0  67.0  66.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  72.0  69.0  67.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  25.0  17.0  17.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    wk75  wk76
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# ...

# %%
bilboard.columns
# Out:
# Index(['year', 'artist', 'track', 'time', 'date.entered', 'wk1', 'wk2', 'wk3',
#        'wk4', 'wk5', 'wk6', 'wk7', 'wk8', 'wk9', 'wk10', 'wk11', 'wk12',
#        'wk13', 'wk14', 'wk15', 'wk16', 'wk17', 'wk18', 'wk19', 'wk20', 'wk21',
#        'wk22', 'wk23', 'wk24', 'wk25', 'wk26', 'wk27', 'wk28', 'wk29', 'wk30',
#        'wk31', 'wk32', 'wk33', 'wk34', 'wk35', 'wk36', 'wk37', 'wk38', 'wk39',
#        'wk40', 'wk41', 'wk42', 'wk43', 'wk44', 'wk45', 'wk46', 'wk47', 'wk48',
#        'wk49', 'wk50', 'wk51', 'wk52', 'wk53', 'wk54', 'wk55', 'wk56', 'wk57',
#        'wk58', 'wk59', 'wk60', 'wk61', 'wk62', 'wk63', 'wk64', 'wk65', 'wk66',
#        'wk67', 'wk68', 'wk69', 'wk70', 'wk71', 'wk72', 'wk73', 'wk74', 'wk75',
#        'wk76'],
#       dtype='object')

# %%
billboard_melted = pd.melt(
    bilboard, 
    id_vars=['year', 'artist', 'track', 'time', 'date.entered'],
    value_vars=[
        'wk1', 'wk2', 'wk3', 'wk4', 'wk5', 'wk6', 'wk7', 'wk8', 'wk9','wk10', 'wk11',
        'wk12','wk13', 'wk14', 'wk15', 'wk16', 'wk17', 'wk18', 'wk19', 'wk20', 'wk21',
        'wk22', 'wk23', 'wk24', 'wk25', 'wk26', 'wk27', 'wk28', 'wk29', 'wk30','wk31',
        'wk32', 'wk33', 'wk34', 'wk35', 'wk36', 'wk37', 'wk38', 'wk39','wk40', 'wk41',
        'wk42', 'wk43', 'wk44', 'wk45', 'wk46', 'wk47', 'wk48','wk49', 'wk50', 'wk51',
        'wk52', 'wk53', 'wk54', 'wk55', 'wk56', 'wk57','wk58', 'wk59', 'wk60', 'wk61',
        'wk62', 'wk63', 'wk64', 'wk65', 'wk66','wk67', 'wk68', 'wk69', 'wk70', 'wk71',
        'wk72', 'wk73', 'wk74', 'wk75','wk76'
        ],
       var_name='week',
       value_name='rank'
    )

# %%
billboard_melted
# Out:
#        year            artist                    track  time date.entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  rank
# 0       wk1  87.0
# 1       wk1  91.0
# 2       wk1  81.0
# ...

# %%
billboard_melted.dtypes
# Out:
# year              int64
# artist           object
# track            object
# time             object
# date.entered     object
# week             object
# rank            float64
# dtype: object

# %%
billboard_melted_na_dropped = billboard_melted.dropna()

# %%
billboard_melted_na_dropped['rank'] = billboard_melted_na_dropped['rank'].astype(int)
# Out:
# /var/folders/n3/_b2k9ztj2rs2r_ykbrv076hr0000gq/T/ipykernel_67146/3793205164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billboard_melted_na_dropped['rank'] = billboard_melted_na_dropped['rank'].astype(int)

# %%
billboard_melted_na_dropped.dtypes
# Out:
# year             int64
# artist          object
# track           object
# time            object
# date.entered    object
# week            object
# rank             int64
# dtype: object

# %%
billboard_melted_na_dropped['week'] = billboard_melted_na_dropped['week'].str[2:].astype(int)
# Out:
# /var/folders/n3/_b2k9ztj2rs2r_ykbrv076hr0000gq/T/ipykernel_67146/3683029436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   billboard_melted_na_dropped['week'] = billboard_melted_na_dropped['week'].str[2:].astype(int)

# %%
billboard_melted_na_dropped = billboard_melted_na_dropped.drop(columns = 'year')

# %%
billboard_melted_na_dropped
# Out:
#              artist                    track  time date.entered  week  rank
# 0             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26     1    87
# 1           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02     1    91
# 2      3 Doors Down               Kryptonite  3:53   2000-04-08     1    81
# 3      3 Doors Down                    Loser  4:24   2000-10-21     1    76
# 4          504 Boyz            Wobble Wobble  3:35   2000-04-15     1    57
# ...             ...                      ...   ...          ...   ...   ...
# 19716         Creed                   Higher  5:16   1999-09-11    63    50
# 19833      Lonestar                   Amazed  4:25   1999-06-05    63    45
# 20033         Creed                   Higher  5:16   1999-09-11    64    50
# 20150      Lonestar                   Amazed  4:25   1999-06-05    64    50
# 20350         Creed                   Higher  5:16   1999-09-11    65    49
#
# [5307 rows x 6 columns]

# %%
billboard_melted_na_dropped[billboard_melted_na_dropped['track'] == 'Loser']
# Out:
#             artist  track  time date.entered  week  rank
# 3     3 Doors Down  Loser  4:24   2000-10-21     1    76
# 320   3 Doors Down  Loser  4:24   2000-10-21     2    76
# 637   3 Doors Down  Loser  4:24   2000-10-21     3    72
# 954   3 Doors Down  Loser  4:24   2000-10-21     4    69
# 1271  3 Doors Down  Loser  4:24   2000-10-21     5    67
# 1588  3 Doors Down  Loser  4:24   2000-10-21     6    65
# 1905  3 Doors Down  Loser  4:24   2000-10-21     7    55
# 2222  3 Doors Down  Loser  4:24   2000-10-21     8    59
# 2539  3 Doors Down  Loser  4:24   2000-10-21     9    62
# 2856  3 Doors Down  Loser  4:24   2000-10-21    10    61
# 3173  3 Doors Down  Loser  4:24   2000-10-21    11    61
# 3490  3 Doors Down  Loser  4:24   2000-10-21    12    59
# 3807  3 Doors Down  Loser  4:24   2000-10-21    13    61
# 4124  3 Doors Down  Loser  4:24   2000-10-21    14    66
# 4441  3 Doors Down  Loser  4:24   2000-10-21    15    72
# ...

# %%
billboard_melted_na_dropped
# Out:
#              artist                    track  time date.entered  week  rank
# 0             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26     1    87
# 1           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02     1    91
# 2      3 Doors Down               Kryptonite  3:53   2000-04-08     1    81
# 3      3 Doors Down                    Loser  4:24   2000-10-21     1    76
# 4          504 Boyz            Wobble Wobble  3:35   2000-04-15     1    57
# ...             ...                      ...   ...          ...   ...   ...
# 19716         Creed                   Higher  5:16   1999-09-11    63    50
# 19833      Lonestar                   Amazed  4:25   1999-06-05    63    45
# 20033         Creed                   Higher  5:16   1999-09-11    64    50
# 20150      Lonestar                   Amazed  4:25   1999-06-05    64    50
# 20350         Creed                   Higher  5:16   1999-09-11    65    49
#
# [5307 rows x 6 columns]

# %%
pd.to_datetime(billboard_melted_na_dropped['date.entered'], format='%Y-%m-%d')
# Out:
# 0       2000-02-26
# 1       2000-09-02
# 2       2000-04-08
# 3       2000-10-21
# 4       2000-04-15
#            ...
# 19716   1999-09-11
# 19833   1999-06-05
# 20033   1999-09-11
# 20150   1999-06-05
# 20350   1999-09-11
# Name: date.entered, Length: 5307, dtype: datetime64[ns]

# %%
billboard_melted_na_dropped['date.entered'] = pd.to_datetime(billboard_melted_na_dropped['date.entered'], format='%Y-%m-%d')

# %%
billboard_melted_na_dropped.dtypes
# Out:
# artist                  object
# track                   object
# time                    object
# date.entered    datetime64[ns]
# week                     int64
# rank                     int64
# dtype: object

# %%
billboard_melted_na_dropped[billboard_melted_na_dropped['track'] == 'Loser']['date.entered'] + pd.Timedelta(billboard_melted_na_dropped[billboard_melted_na_dropped['track'] == 'Loser']['week'], unit='W')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 billboard_melted_na_dropped[billboard_melted_na_dropped['track'] == 'Loser']['date.entered'] + pd.Timedelta(billboard_melted_na_dropped[billboard_melted_na_dropped['track'] == 'Loser']['week'], unit='W')
#
# File timedeltas.pyx:1900, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: Value must be Timedelta, string, integer, float, timedelta or convertible, not Series

# %%
billboard_melted_na_dropped['adjusted_date'] = (
    billboard_melted_na_dropped['date.entered'] 
    + pd.to_timedelta(billboard_melted_na_dropped['week'], unit='W')
)

# %%
billboard_melted_na_dropped
# Out:
#                      artist                    track  time date.entered week  \
# 0                     2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26    1
# 1                   2Ge+her  The Hardest Part Of ...  3:15   2000-09-02    1
# 2              3 Doors Down               Kryptonite  3:53   2000-04-08    1
# 3              3 Doors Down                    Loser  4:24   2000-10-21    1
# 4                  504 Boyz            Wobble Wobble  3:35   2000-04-15    1
# ...                     ...                      ...   ...          ...  ...
# 19833              Lonestar                   Amazed  4:25   1999-06-05   63
# 20033                 Creed                   Higher  5:16   1999-09-11   64
# 20150              Lonestar                   Amazed  4:25   1999-06-05   64
# 20350                 Creed                   Higher  5:16   1999-09-11   65
# adjusted_date           NaN                      NaN   NaN          NaT  NaT
#
#               rank adjusted_date
# ...

# %%
billboard_melted_na_dropped.drop(columns=['date.entered'], inplace=True)

# %%
billboard_melted_na_dropped
# Out:
#                      artist                    track  time week rank  \
# 0                     2 Pac  Baby Don't Cry (Keep...  4:22    1   87
# 1                   2Ge+her  The Hardest Part Of ...  3:15    1   91
# 2              3 Doors Down               Kryptonite  3:53    1   81
# 3              3 Doors Down                    Loser  4:24    1   76
# 4                  504 Boyz            Wobble Wobble  3:35    1   57
# ...                     ...                      ...   ...  ...  ...
# 19833              Lonestar                   Amazed  4:25   63   45
# 20033                 Creed                   Higher  5:16   64   50
# 20150              Lonestar                   Amazed  4:25   64   50
# 20350                 Creed                   Higher  5:16   65   49
# adjusted_date           NaN                      NaN   NaN  NaT  NaT
#
#               adjusted_date
# 0                2000-03-04
# 1                2000-09-09
# 2                2000-04-15
# ...

# %%
billboard_melted_na_dropped.dropna(inplace=True)

# %%
billboard_melted_na_dropped
# Out:
#              artist                    track  time week rank adjusted_date
# 0             2 Pac  Baby Don't Cry (Keep...  4:22    1   87    2000-03-04
# 1           2Ge+her  The Hardest Part Of ...  3:15    1   91    2000-09-09
# 2      3 Doors Down               Kryptonite  3:53    1   81    2000-04-15
# 3      3 Doors Down                    Loser  4:24    1   76    2000-10-28
# 4          504 Boyz            Wobble Wobble  3:35    1   57    2000-04-22
# ...             ...                      ...   ...  ...  ...           ...
# 19716         Creed                   Higher  5:16   63   50    2000-11-25
# 19833      Lonestar                   Amazed  4:25   63   45    2000-08-19
# 20033         Creed                   Higher  5:16   64   50    2000-12-02
# 20150      Lonestar                   Amazed  4:25   64   50    2000-08-26
# 20350         Creed                   Higher  5:16   65   49    2000-12-09
#
# [5307 rows x 6 columns]

# %%
billboard_melted_na_dropped.columns = ['artist', 'track', 'time', 'week', 'rank', 'day']

# %%
billboard_melted_na_dropped.drop(columns='week', inplace=True)

# %%
billboard_melted_na_dropped[['day', 'artist', 'track', 'time', 'rank']]
# Out:
#              day        artist                    track  time rank
# 0     2000-03-04         2 Pac  Baby Don't Cry (Keep...  4:22   87
# 1     2000-09-09       2Ge+her  The Hardest Part Of ...  3:15   91
# 2     2000-04-15  3 Doors Down               Kryptonite  3:53   81
# 3     2000-10-28  3 Doors Down                    Loser  4:24   76
# 4     2000-04-22      504 Boyz            Wobble Wobble  3:35   57
# ...          ...           ...                      ...   ...  ...
# 19716 2000-11-25         Creed                   Higher  5:16   50
# 19833 2000-08-19      Lonestar                   Amazed  4:25   45
# 20033 2000-12-02         Creed                   Higher  5:16   50
# 20150 2000-08-26      Lonestar                   Amazed  4:25   50
# 20350 2000-12-09         Creed                   Higher  5:16   49
#
# [5307 rows x 5 columns]

# %%
loser_data = billboard_melted_na_dropped[billboard_melted_na_dropped['track'] == 'Loser']

# %%
plt.figure(figsize=(12, 8))
plt.plot(loser_data['day'], loser_data['rank'])
plt.show()
