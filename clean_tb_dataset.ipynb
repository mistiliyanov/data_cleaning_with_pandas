# %%
# my imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Cleanining Project "Tuberculosis"

# %%
pd.read_csv('data/tb.csv')
# Out:
#      iso2  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  ...  \
# 0      AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 1      AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 2      AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 3      AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 4      AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# ...   ...   ...  ...    ...    ...    ...     ...     ...     ...    ...  ...
# 5764   ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0  ...
# 5765   ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0  ...
# 5766   ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0  ...
# 5767   ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0  ...
# 5768   ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0  ...
#
# ...

# %%
tb = pd.read_csv('data/tb.csv')

# %%
tb.columns
# Out:
# Index(['iso2', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
pd.melt(tb,
        id_vars = ['iso2', 'year'],
        value_vars= ['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
       'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
       'f3544', 'f4554', 'f5564', 'f65', 'fu'],
       var_name='gender_age_group',
       value_name='cases')
# Out:
#        iso2  year gender_age_group  cases
# 0        AD  1989              m04    NaN
# 1        AD  1990              m04    NaN
# 2        AD  1991              m04    NaN
# 3        AD  1992              m04    NaN
# 4        AD  1993              m04    NaN
# ...     ...   ...              ...    ...
# 115375   ZW  2004               fu    NaN
# 115376   ZW  2005               fu    NaN
# 115377   ZW  2006               fu    NaN
# 115378   ZW  2007               fu    NaN
# 115379   ZW  2008               fu    0.0
#
# [115380 rows x 4 columns]

# %%
tb_melted = pd.melt(tb,
        id_vars = ['iso2', 'year'],
        value_vars= ['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
       'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
       'f3544', 'f4554', 'f5564', 'f65', 'fu'],
       var_name='gender_age_group',
       value_name='cases')

# %%
tb_melted_na_dropped =  tb_melted.dropna()

# %%
tb_melted_na_dropped['cases'] = tb_melted_na_dropped['cases'].astype(int)
# Out:
# /var/folders/n3/_b2k9ztj2rs2r_ykbrv076hr0000gq/T/ipykernel_17521/806787791.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_melted_na_dropped['cases'] = tb_melted_na_dropped['cases'].astype(int)

# %%
tb_melted_na_dropped.dtypes
# Out:
# iso2                object
# year                 int64
# gender_age_group    object
# cases                int64
# dtype: object

# %%
tb_melted_na_dropped[(tb_melted_na_dropped['gender_age_group'] == 'mu') &
                     (tb_melted_na_dropped['cases'] > 0)]
# Out:
#       iso2  year gender_age_group  cases
# 52165   AR  2008               mu     30
# 52307   BA  2005               mu      1
# 52308   BA  2006               mu      2
# 53498   EG  2008               mu      8
# 53541   ES  2005               mu      2
# 53542   ES  2006               mu      2
# 53543   ES  2007               mu      2
# 53687   FR  2008               mu      1
# 53743   GB  2007               mu      1
# 53798   GE  2007               mu      1
# 53916   GR  2005               mu      5
# 53917   GR  2006               mu      3
# 53918   GR  2007               mu      1
# 54225   IE  2006               mu      1
# 54398   IT  2005               mu     24
# 54399   IT  2006               mu     19
# 54400   IT  2007               mu     11
# 54401   IT  2008               mu      5
# 54430   JM  2008               mu      2
# 55143   ME  2007               mu      1
# 55212   MK  2005               mu      1
# 55582   MY  2008               mu      2
# ...

# %%
tb_melted_na_dropped['gender_age_group'].unique()
# Out:
# array(['m04', 'm514', 'm014', 'm1524', 'm2534', 'm3544', 'm4554', 'm5564',
#        'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534', 'f3544',
#        'f4554', 'f5564', 'f65', 'fu'], dtype=object)

# %%
tb_melted_na_dropped
# Out:
#        iso2  year gender_age_group  cases
# 15       AD  2005              m04      0
# 16       AD  2006              m04      0
# 18       AD  2008              m04      0
# 42       AE  2006              m04      0
# 43       AE  2007              m04      0
# ...     ...   ...              ...    ...
# 115195   VU  2008               fu      0
# 115269   YE  2008               fu      0
# 115323   ZA  2008               fu      0
# 115350   ZM  2008               fu      0
# 115379   ZW  2008               fu      0
#
# [35552 rows x 4 columns]

# %%
tb_melted_na_dropped['gender'] = tb_melted_na_dropped['gender_age_group'].str.slice(0,1)
# Out:
# /var/folders/n3/_b2k9ztj2rs2r_ykbrv076hr0000gq/T/ipykernel_17521/1428084937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_melted_na_dropped['gender'] = tb_melted_na_dropped['gender_age_group'].str.slice(0,1)

# %%
tb_melted_na_dropped['gender'].unique()
# Out:
# array(['m', 'f'], dtype=object)

# %%
tb_melted_na_dropped['age_group'] = tb_melted_na_dropped['gender_age_group'].str.slice(1)
# Out:
# /var/folders/n3/_b2k9ztj2rs2r_ykbrv076hr0000gq/T/ipykernel_17521/3895064814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_melted_na_dropped['age_group'] = tb_melted_na_dropped['gender_age_group'].str.slice(1)

# %%
tb_melted_na_dropped['age_group'].unique()
# Out:
# array(['04', '514', '014', '1524', '2534', '3544', '4554', '5564', '65',
#        'u'], dtype=object)

# %%
def process_age_group(age_group):
    ages = {"04": "0-14", "014": "0-14", "514": "0-14", "65": "65+", "u": "unknown"}
    if age_group in ages:
        return ages[age_group]
    else:
        # Put a dash before the last two digits
        return f"{age_group[:-2]}-{age_group[-2:]}"

process_age_group('04')
# Out:
# '0-14'

# %%
tb_melted_na_dropped['age_group'] = tb_melted_na_dropped['age_group'].apply(process_age_group)
# Out:
# /var/folders/n3/_b2k9ztj2rs2r_ykbrv076hr0000gq/T/ipykernel_17521/2863449999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tb_melted_na_dropped['age_group'] = tb_melted_na_dropped['age_group'].apply(process_age_group)

# %%
tb_melted_na_dropped
# Out:
#        iso2  year gender_age_group  cases gender age_group
# 15       AD  2005              m04      0      m      0-14
# 16       AD  2006              m04      0      m      0-14
# 18       AD  2008              m04      0      m      0-14
# 42       AE  2006              m04      0      m      0-14
# 43       AE  2007              m04      0      m      0-14
# ...     ...   ...              ...    ...    ...       ...
# 115195   VU  2008               fu      0      f   unknown
# 115269   YE  2008               fu      0      f   unknown
# 115323   ZA  2008               fu      0      f   unknown
# 115350   ZM  2008               fu      0      f   unknown
# 115379   ZW  2008               fu      0      f   unknown
#
# [35552 rows x 6 columns]

# %%
tb_melted_na_dropped.drop(columns=['gender_age_group'])
# Out:
#        iso2  year  cases gender age_group
# 15       AD  2005      0      m      0-14
# 16       AD  2006      0      m      0-14
# 18       AD  2008      0      m      0-14
# 42       AE  2006      0      m      0-14
# 43       AE  2007      0      m      0-14
# ...     ...   ...    ...    ...       ...
# 115195   VU  2008      0      f   unknown
# 115269   YE  2008      0      f   unknown
# 115323   ZA  2008      0      f   unknown
# 115350   ZM  2008      0      f   unknown
# 115379   ZW  2008      0      f   unknown
#
# [35552 rows x 5 columns]

# %%
tb_melted_na_dropped = tb_melted_na_dropped[['iso2', 'year', 'gender', 'age_group', 'cases']]

# %%
tb_melted_na_dropped
# Out:
#        iso2  year gender age_group  cases
# 15       AD  2005      m      0-14      0
# 16       AD  2006      m      0-14      0
# 18       AD  2008      m      0-14      0
# 42       AE  2006      m      0-14      0
# 43       AE  2007      m      0-14      0
# ...     ...   ...    ...       ...    ...
# 115195   VU  2008      f   unknown      0
# 115269   YE  2008      f   unknown      0
# 115323   ZA  2008      f   unknown      0
# 115350   ZM  2008      f   unknown      0
# 115379   ZW  2008      f   unknown      0
#
# [35552 rows x 5 columns]

# %%
tb_2005 = tb_melted_na_dropped[tb_melted_na_dropped['year'] == 2005]

# %%
tb_2005
# Out:
#        iso2  year gender age_group  cases
# 15       AD  2005      m      0-14      0
# 141      AL  2005      m      0-14      0
# 170      AM  2005      m      0-14      1
# 299      AT  2005      m      0-14      1
# 357      AZ  2005      m      0-14      2
# ...     ...   ...    ...       ...    ...
# 114281   SI  2005      f   unknown      0
# 114310   SK  2005      f   unknown      0
# 114673   TJ  2005      f   unknown      0
# 114735   TM  2005      f   unknown      0
# 114820   TR  2005      f   unknown      0
#
# [2820 rows x 5 columns]

# %%
plt.bar(tb_2005['age_group'], tb_2005['cases'])
plt.title('TB cases per age group 2005')
plt.show()
